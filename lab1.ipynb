# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data=pd.read_csv('new.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
print(data)
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
print(data.shape)
print(data.columns)
# Out:
# (48895, 16)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %%
data.at[2, 'host_name']
# Out:
# 'Elisabeth'

# %%
data['host_name']
# Out:
# 0                    John
# 1                Jennifer
# 2               Elisabeth
# 3             LisaRoxanne
# 4                   Laura
# 5                   Chris
# 6                   Garon
# 7                Shunichi
# 8               MaryEllen
# 9                     Ben
# 10                   Lena
# 11                   Kate
# 12                 Laurie
# 13                Claudio
# 14                  Alina
# 15          Allen & Irina
# 16                   Jane
# 17                   Doti
# 18       Adam And Charity
# 19                   Sing
# 20                  Chaya
# 21                  Lisel
# 22                  Lisel
# 23                  Lisel
# 24               Nathalie
# 25                Gregory
# 26        Claude & Sophie
# 27                  Tommi
# 28                   Shon
# 29                   Dana
#                ...
# 48865              Brenda
# 48866             Alberth
# 48867               Diana
# 48868               Diana
# ...

# %%
data['host_name'][3]
# Out:
# 'LisaRoxanne'

# %%
data['minimum_nights'].dtype.name
# Out:
# 'int64'

# %%
type(data['price'][3])
# Out:
# numpy.int64

# %%
data[['host_name', 'neighbourhood_group']].head()
# Out:
#      host_name neighbourhood_group
# 0         John            Brooklyn
# 1     Jennifer           Manhattan
# 2    Elisabeth           Manhattan
# 3  LisaRoxanne            Brooklyn
# 4        Laura           Manhattan

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
data.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588290 -0.003125   0.090908
# host_id                         0.588290  1.000000  0.020224   0.127055
# latitude                       -0.003125  0.020224  1.000000   0.084788
# longitude                       0.090908  0.127055  0.084788   1.000000
# price                           0.010619  0.015309  0.033939  -0.150019
# minimum_nights                 -0.013224 -0.017364  0.024869  -0.062747
# number_of_reviews              -0.319760 -0.140106 -0.015389   0.059094
# reviews_per_month               0.291828  0.296417 -0.010142   0.145948
# calculated_host_listings_count  0.133272  0.154950  0.019517  -0.114713
# availability_365                0.085468  0.203492 -0.010983   0.082731
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.010619       -0.013224          -0.319760
# ...

# %%
plt.plot(data['number_of_reviews'], data['price'], 'o', alpha = 0.05)
plt.xlabel('number_of_reviews')
plt.ylabel('price')
plt.title('Number_of_reviews vs price')
pass

# %%
data['minimum_nights'] == 1
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9         True
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 48865     True
# 48866     True
# 48867     True
# 48868    False
# 48869    False
# 48870    False
# 48871    False
# 48872    False
# 48873     True
# 48874    False
# 48875     True
# 48876     True
# 48877    False
# 48878     True
# 48879    False
# 48880     True
# 48881    False
# 48882    False
# 48883    False
# 48884    False
# 48885    False
# 48886    False
# 48887     True
# 48888    False
# 48889     True
# 48890    False
# 48891    False
# ...

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['minimum_nights'] == 1]['number_of_reviews'],
            data[data['minimum_nights'] == 1]['price'],
            alpha = 0.15,
            label = 1,
            color = 'b')

plt.scatter(data[data['minimum_nights'] == 3]['number_of_reviews'],
            data[data['minimum_nights'] == 3]['price'],
            alpha = 0.05,
            label = 3,
            color = 'r')

plt.xlabel('minimum_nights')
plt.xticks(range(18))
plt.xlim(0, 17)
plt.ylabel('price')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
pnumber_of_reviews_rnd = data['number_of_reviews'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (10, 8))

plt.scatter(pnumber_of_reviews_rnd[data['minimum_nights'] == 1],
            data[data['minimum_nights'] == 1]['price'],
            alpha = 0.15,
            label = 1,
            color = 'b')

plt.scatter(pnumber_of_reviews_rnd[data['minimum_nights'] == 3],
            data[data['minimum_nights'] == 3]['price'],
            alpha = 0.15,
            label = 3,
            color = 'r')

plt.xlabel('number_of_reviews')
plt.xticks(range(17))
plt.xlim(0, 17)
plt.ylabel('price')
plt.title('')
plt.grid()

# %%
plt.figure(figsize = (10, 8))


plt.scatter(data[data['minimum_nights'] == 2]['number_of_reviews'],
            data[data['minimum_nights'] == 2]['price'],
            alpha = 0.15,
            label = 2,
            color = 'r')

plt.scatter(data[data['minimum_nights'] == 1]['number_of_reviews'],
            data[data['minimum_nights'] == 1]['price'],
            alpha = 0.15,
            label = 1,
            color = 'b')

plt.xlabel('number_of_reviews')
plt.ylabel('price')
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                   name host_name neighbourhood_group neighbourhood  \
# count            48879     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                18       417               21661          3920
#
#               room_type last_review
# count             48895       38843
# unique                3        1764
# top     Entire home/apt  2019-06-23
# freq              25409        1413

# %%
data.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
for name in data['neighbourhood_group'].unique():
    print(name, data['price'][data['neighbourhood_group'] == name].iloc[0])
# Out:
# Brooklyn 149
# Manhattan 225
# Queens 130
# Staten Island 70
# Bronx 40

# %%
data['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
data.drop(['number_of_reviews'], axis = 1)
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
data['name'].dtype.name
# Out:
# 'object'

# %%
data['id'].dtype.name
# Out:
# 'int64'

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'last_review']
# ['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# name ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# host_name ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# neighbourhood_group ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# neighbourhood ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
# ...

# %%
data.median(axis = 0)
# Out:
# id                                1.967728e+07
# host_id                           3.079382e+07
# latitude                          4.072307e+01
# longitude                        -7.395568e+01
# price                             1.060000e+02
# minimum_nights                    3.000000e+00
# number_of_reviews                 5.000000e+00
# reviews_per_month                 7.200000e-01
# calculated_host_listings_count    1.000000e+00
# availability_365                  4.500000e+01
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# id                                48895
# host_id                           48895
# latitude                          48895
# longitude                         48895
# price                             48895
# minimum_nights                    48895
# number_of_reviews                 48895
# reviews_per_month                 48895
# calculated_host_listings_count    48895
# availability_365                  48895
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# name                   48879
# host_name              48874
# neighbourhood_group    48895
# neighbourhood          48895
# room_type              48895
# last_review            38843
# dtype: int64

# %%
data['id'].describe()
# Out:
# count    4.889500e+04
# mean     1.901714e+07
# std      1.098311e+07
# min      2.539000e+03
# 25%      9.471945e+06
# 50%      1.967728e+07
# 75%      2.915218e+07
# max      3.648724e+07
# Name: id, dtype: float64

# %%
type(data['name'].describe())
# Out:
# pandas.core.series.Series

# %%
data['name'].describe().top
# Out:
# 'Hillside Hotel'

# %%
data['name'] = data['name'].fillna('Hillside Hotel')

# %%
data.describe(include = [object])
# Out:
#                   name host_name neighbourhood_group neighbourhood  \
# count            48895     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                34       417               21661          3920
#
#               room_type last_review
# count             48895       38843
# unique                3        1764
# top     Entire home/apt  2019-06-23
# freq              25409        1413

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#                   name host_name neighbourhood_group neighbourhood  \
# count            48895     48895               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                34       438               21661          3920
#
#               room_type last_review
# count             48895       48895
# unique                3        1764
# top     Entire home/apt  2019-06-23
# freq              25409       11465

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 3]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] >= 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['room_type'] ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'last_review']

# %%
data['host_name'].unique()
# Out:
# array(['John', 'Jennifer', 'Elisabeth', ..., 'Abayomi', 'Alberth',
#        'Ilgar & Aysel'], dtype=object)

# %%
data.at[data['host_name'] == 'John', 'host_name'] = 0
data.at[data['host_name'] == 'Jennifer', 'host_name'] = 1
data['host_name'].describe()
# Out:
# count       48895
# unique      11452
# top       Michael
# freq          438
# Name: host_name, dtype: object

# %%
data['last_review'].unique()
# Out:
# array(['2018-10-19', '2019-05-21', '2019-06-23', ..., '2017-12-23',
#        '2018-01-29', '2018-03-29'], dtype=object)

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['name_ 1 Bed Apt in Utopic Williamsburg ',
#        'name_ 2-3 bedroom UWS garden triplex ',
#        'name_ 3 bedroom loft in Williamsburg',
#        'name_ A charming Space in Brooklyn ',
#        'name_ AMAZING TIME SQUARE!!BRICK WALLS!!', 'name_ Affordable & Cozy ',
#        'name_ Beautiful Room In Gramercy!!!',
#        'name_ Family Friendly Brooklyn House',
#        'name_ Heart & Soul of Greenwich Village ',
#        'name_ Private 1 bdrm Lefferts Gr, BK apt',
#        ...
#        'last_review_2019-06-29', 'last_review_2019-06-30',
#        'last_review_2019-07-01', 'last_review_2019-07-02',
#        'last_review_2019-07-03', 'last_review_2019-07-04',
#        'last_review_2019-07-05', 'last_review_2019-07-06',
#        'last_review_2019-07-07', 'last_review_2019-07-08'],
#       dtype='object', length=61350)

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.238930
# std         20.510550          44.550582           1.520861
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  4.889500e+04  4.889500e+04  4.889500e+04
# mean  -1.591056e-15 -3.389339e-15 -1.002942e-12 -1.368856e-11  5.465285e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.731259e+00 -8.601544e-01 -4.202431e+00 -6.331695e+00 -6.359277e-01
# 25%   -8.690799e-01 -7.606824e-01 -7.124303e-01 -6.694664e-01 -3.486123e-01
# 50%    6.010509e-02 -4.684613e-01 -1.078099e-01 -7.605359e-02 -1.945446e-01
# 75%    9.227839e-01  5.064740e-01  6.265555e-01  3.443618e-01  9.277088e-02
# max    1.590634e+00  2.629421e+00  3.376322e+00  5.181901e+00  4.100399e+01
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    4.889500e+04       4.889500e+04       4.889500e+04
# mean    -1.811327e-15       3.547264e-15      -6.979299e-14
# std      1.000000e+00       1.000000e+00       1.000000e+00
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.238930
# std         20.510550          44.550582           1.520861
# ...

# %%
X = data.drop(('price'), axis = 1) 
y = data['price']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (48895, 15)
# (48895,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 34226 14669

# %%
34226+14669
# Out:
# 48895

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-1d13dd55c672> in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 knn = KNeighborsClassifier(n_neighbors = 5)
# ----> 3 knn.fit(X_train, y_train)
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     890         """
#     891         if not isinstance(X, (KDTree, BallTree)):
# --> 892             X, y = check_X_y(X, y, "csr", multi_output=True)
#     893
#     894         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-06c142074813> in <module>
# ----> 1 y_train_predict = knn.predict(X_train)
#       2 y_test_predict = knn.predict(X_test)
#       3
#       4 err_train = np.mean(y_train != y_train_predict)
#       5 err_test  = np.mean(y_test  != y_test_predict)
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     145             Class labels for each data sample.
#     146         """
# --> 147         X = check_array(X, accept_sparse='csr')
#     148
#     149         neigh_dist, neigh_ind = self.kneighbors(X)
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
err_test = 1 - knn.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-15d9c7ac0098> in <module>
# ----> 1 err_test = 1 - knn.score(X_test, y_test)
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     355         """
#     356         from .metrics import accuracy_score
# --> 357         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     358
#     359
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     145             Class labels for each data sample.
#     146         """
# --> 147         X = check_array(X, accept_sparse='csr')
#     148
#     149         neigh_dist, neigh_ind = self.kneighbors(X)
#
# ...

# %%
err_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-234ec30c2448> in <module>
# ----> 1 err_test
#
# NameError: name 'err_test' is not defined

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-176f990f95a6> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2
# ----> 3 print(confusion_matrix(y_test, y_test_predict))
#
# NameError: name 'y_test_predict' is not defined

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-65989e1eca8b> in <module>
#       3 knn = KNeighborsClassifier()
#       4 grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
# ----> 5 grid.fit(X_train, y_train)
#       6
# ...

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f13e8b9a26e1> in <module>
# ----> 1 knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)
#       2
#       3 err_train = np.mean(y_train != knn.predict(X_train))
#       4 err_test  = np.mean(y_test  != knn.predict(X_test))
#       5
#
# NameError: name 'best_n_neighbors' is not defined

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-d5e89f02a72f> in <module>
#       1 from sklearn.svm import SVC
#       2 svc = SVC()
# ----> 3 svc.fit(X_train, y_train)
#       4
#       5 err_train = np.mean(y_train != svc.predict(X_train))
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     144         X, y = check_X_y(X, y, dtype=np.float64,
#     145                          order='C', accept_sparse='csr',
# --> 146                          accept_large_sparse=False)
#     147         y = self._validate_targets(y)
#     148
#
# ...

# %% [markdown]
# Подбор параметров

# %%
from sklearn.grid_search import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-78-0a1e30bfbbb6> in <module>
# ----> 1 from sklearn.grid_search import GridSearchCV
#       2 Cs = 10.**np.arange(-5, 5)
#       3 gamma_array = 10.**np.arange(-5, 5)
#       4 svc = SVC()
#       5 grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
#
# ModuleNotFoundError: No module named 'sklearn.grid_search'

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-717c4b5afdf6> in <module>
# ----> 1 svc = SVC(C = best_C).fit(X_train, y_train)
#       2
#       3 err_train = np.mean(y_train != knn.predict(X_train))
#       4 err_test  = np.mean(y_test  != knn.predict(X_test))
#       5
#
# NameError: name 'best_C' is not defined

# %% [markdown]
# Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-17ef9fb0a7ff> in <module>
#       1 from sklearn import ensemble
#       2 rf = ensemble.RandomForestClassifier(n_estimators = 1000)
# ----> 3 rf.fit(X_train, y_train)
#       4
#       5 err_train = np.mean(y_train != rf.predict(X_train))
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# ...

# %% [markdown]
# Значимость признаков

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-82-7851b2f23533> in <module>
# ----> 1 np.sum(rf.feature_importances_)
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in feature_importances_(self)
#     371             array of zeros.
#     372         """
# --> 373         check_is_fitted(self, 'estimators_')
#     374
#     375         all_importances = Parallel(n_jobs=self.n_jobs,
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# ...

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-83-42f0e374b94b> in <module>
# ----> 1 importances = rf.feature_importances_
#       2 indices = np.argsort(importances)[::-1]
#       3
#       4 print("Feature ranking:")
#       5
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in feature_importances_(self)
#     371             array of zeros.
#     372         """
# --> 373         check_is_fitted(self, 'estimators_')
#     374
#     375         all_importances = Parallel(n_jobs=self.n_jobs,
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# ...

# %%
feature_names[[1,0,1]]
# Out:
# Index(['name', 'id', 'name'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-43161fedf69e> in <module>
#       1 d_first = 20
#       2 plt.title("Feature importances")
# ----> 3 plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
#       4 plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
#       5 plt.xlim([-1, d_first])
#
# NameError: name 'importances' is not defined

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-1951a5383e94> in <module>
# ----> 1 ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)
#       2
#       3 err_train = np.mean(y_train != ert.predict(X_train))
#       4 err_test  = np.mean(y_test  != ert.predict(X_test))
#       5
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# ...

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-ded981e3c8dd> in <module>
#       1 ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
# ----> 2 ada.fit(X_train, y_train)
#       3
#       4 err_train = np.mean(y_train != ada.predict(X_train))
#       5 err_test = np.mean(y_test != ada.predict(X_test))
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     425
#     426         # Fit
# --> 427         return super().fit(X, y, sample_weight)
#     428
#     429     def _validate_estimator(self):
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     148                 X, y,
#     149                 sample_weight,
# --> 150                 random_state)
#     151
#     152             # Early termination
#
# ...

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-34d15fdd5a02> in <module>
#       1 gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
# ----> 2 gbt.fit(X_train, y_train)
#       3
#       4 err_train = np.mean(y_train != gbt.predict(X_train))
#       5 err_test = np.mean(y_test != gbt.predict(X_test))
#
# C:\ProgramFiles\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1435         # Since check_array converts both X and y to the same dtype, but the
#    1436         # trees use different types for X and y, checking them separately.
# -> 1437         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'], dtype=DTYPE)
#    1438         n_samples, self.n_features_ = X.shape
#    1439
#
# ...
